# %% [markdown]
# ### Import the file from excel and save to a dataframe

# %%
import pandas as pd

df = pd.read_excel (r'C:\Users\Tijesunimi2-PC\Documents\10academy_Telecommunication\Week2_challenge_data_source.xlsx')
df
# Out:
#                    Bearer Id               Start  Start ms  \
# 0       13114483460844900352 2019-04-04 12:01:18     770.0
# 1       13114483482878900224 2019-04-09 13:04:04     235.0
# 2       13114483484080500736 2019-04-09 17:42:11       1.0
# 3       13114483485442799616 2019-04-10 00:31:25     486.0
# 4       13114483499480700928 2019-04-12 20:10:23     565.0
# ...                      ...                 ...       ...
# 149996   7277825670196679680 2019-04-29 07:28:42     451.0
# 149997   7349883264234609664 2019-04-29 07:28:42     483.0
# 149998  13114483573367300096 2019-04-29 07:28:43     283.0
# 149999  13114483573367300096 2019-04-29 07:28:43     696.0
# 150000                                       NaT       NaN
#
#                        End  End ms  Dur. (ms)          IMSI  MSISDN/Number  \
# 0      2019-04-25 14:35:31   662.0  1823652.0  2.082014e+14   3.366496e+10
# 1      2019-04-25 08:15:48   606.0  1365104.0  2.082019e+14   3.368185e+10
# ...

# %% [markdown]
# ### Fill all missing values in the dataset with the mean

# %%
df.fillna(df.mean())
# Out:
#                    Bearer Id               Start  Start ms  \
# 0       13114483460844900352 2019-04-04 12:01:18  770.0000
# 1       13114483482878900224 2019-04-09 13:04:04  235.0000
# 2       13114483484080500736 2019-04-09 17:42:11    1.0000
# 3       13114483485442799616 2019-04-10 00:31:25  486.0000
# 4       13114483499480700928 2019-04-12 20:10:23  565.0000
# ...                      ...                 ...       ...
# 149996   7277825670196679680 2019-04-29 07:28:42  451.0000
# 149997   7349883264234609664 2019-04-29 07:28:42  483.0000
# 149998  13114483573367300096 2019-04-29 07:28:43  283.0000
# 149999  13114483573367300096 2019-04-29 07:28:43  696.0000
# 150000                                       NaT  499.1882
#
#                        End     End ms     Dur. (ms)          IMSI  \
# 0      2019-04-25 14:35:31  662.00000  1.823652e+06  2.082014e+14
# 1      2019-04-25 08:15:48  606.00000  1.365104e+06  2.082019e+14
# ...

# %% [markdown]
# #### Task 1.1 - Aggregate the Number of xDR sessions,  Session duration,  the total download (DL) and upload (UL) data , the total data volume (in Bytes) during this session for each application (Social Media, Google, Email, YouTube, Netflix, Gaming).

# %% [markdown]
# #### Aggregate the Number of xDR sessions

# %%
df.groupby('MSISDN/Number')['Bearer Id'].count()
# Out:
# MSISDN/Number
# 3.360100e+10    1
# 3.360100e+10    1
# 3.360100e+10    1
# 3.360101e+10    1
# 3.360101e+10    2
#                ..
# 3.379000e+10    1
# 3.379000e+10    1
# 3.197021e+12    1
# 3.370000e+14    1
# 8.823971e+14    1
# Name: Bearer Id, Length: 106856, dtype: int64

# %% [markdown]
# #### Aggregate the Session duration

# %%
df.groupby('MSISDN/Number')['Dur. (ms)'].sum()
# Out:
# MSISDN/Number
# 3.360100e+10    116720.0
# 3.360100e+10    181230.0
# 3.360100e+10    134969.0
# 3.360101e+10     49878.0
# 3.360101e+10     37104.0
#                   ...
# 3.379000e+10      8810.0
# 3.379000e+10    140988.0
# 3.197021e+12    877385.0
# 3.370000e+14    253030.0
# 8.823971e+14    869844.0
# Name: Dur. (ms), Length: 106856, dtype: float64

# %% [markdown]
# #### Aggregate the total download (DL) and upload (UL) data

# %%
df.groupby('MSISDN/Number')['Total DL (Bytes)','Total UL (Bytes)'].sum()
# Out:
# C:\Users\Tijesunimi2-PC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                Total DL (Bytes)  Total UL (Bytes)
# MSISDN/Number
# 3.360100e+10       8.426375e+08        36053108.0
# 3.360100e+10       1.207552e+08        36104459.0
# 3.360100e+10       5.566597e+08        39306820.0
# 3.360101e+10       4.019932e+08        20327526.0
# 3.360101e+10       1.363130e+09        94280527.0
# ...                         ...               ...
# 3.379000e+10       6.879252e+08        26716429.0
# 3.379000e+10       4.445751e+08        35732243.0
# 3.197021e+12       1.948281e+08        37295915.0
# 3.370000e+14       5.396350e+08        56652839.0
# 8.823971e+14       7.869760e+07        60456049.0
#
# [106856 rows x 2 columns]

# %% [markdown]
# #### Aggregate the total data volume (in Bytes) during this session for each application (Social Media, Google, Email, YouTube, Netflix, Gaming).

# %%
import numpy as np
df.groupby('MSISDN/Number')['Social Media DL (Bytes)','Social Media UL (Bytes)', 'Google DL (Bytes)', 'Google UL (Bytes)',
                            'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)',
                            'Netflix DL (Bytes)','Netflix UL (Bytes)', 'Gaming DL (Bytes)', 'Gaming UL (Bytes)'].sum()
# Out:
# C:\Users\Tijesunimi2-PC\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.360100e+10                 2206504.0                  25631.0
# 3.360100e+10                 2598548.0                  62017.0
# 3.360100e+10                 3148004.0                  47619.0
# 3.360101e+10                  251469.0                  28825.0
# 3.360101e+10                 2861230.0                  51312.0
# ...                                ...                      ...
# 3.379000e+10                  234320.0                  65863.0
# 3.379000e+10                  442214.0                  56355.0
# 3.197021e+12                  668596.0                  46628.0
# 3.370000e+14                  496337.0                  25229.0
# ...

# %% [markdown]
# #### Start by identifying the top 10 handsets used by the customers.

# %%
df.groupby('Handset Type')['MSISDN/Number'].count().sort_values(ascending=False).head(10)
# Out:
# Handset Type
# Huawei B528S-23A                19727
# Apple iPhone 6S (A1688)          9413
# Apple iPhone 6 (A1586)           9012
# undefined                        8931
# Apple iPhone 7 (A1778)           6304
# Apple iPhone Se (A1723)          5176
# Apple iPhone 8 (A1905)           4985
# Apple iPhone Xr (A2105)          4562
# Samsung Galaxy S8 (Sm-G950F)     4480
# Apple iPhone X (A1901)           3810
# Name: MSISDN/Number, dtype: int64

# %% [markdown]
# #### Then, identify the top 3 handset manufacturers

# %%
df.groupby(['Handset Manufacturer'])['MSISDN/Number'].count().sort_values(ascending=False).head(3)
# Out:
# Handset Manufacturer
# Apple      59464
# Samsung    40579
# Huawei     34366
# Name: MSISDN/Number, dtype: int64

# %% [markdown]
# #### Next, identify the top 5 handsets per handset manufacturer

# %%
df.groupby(['Handset Manufacturer','Handset Type'])['MSISDN/Number'].count().sort_values(ascending=False).head(9)
# Out:
# Handset Manufacturer  Handset Type
# Huawei                Huawei B528S-23A                19727
# Apple                 Apple iPhone 6S (A1688)          9413
#                       Apple iPhone 6 (A1586)           9012
# undefined             undefined                        8931
# Apple                 Apple iPhone 7 (A1778)           6304
#                       Apple iPhone Se (A1723)          5176
#                       Apple iPhone 8 (A1905)           4985
#                       Apple iPhone Xr (A2105)          4562
# Samsung               Samsung Galaxy S8 (Sm-G950F)     4480
# Name: MSISDN/Number, dtype: int64

# %% [markdown]
# #### Make a short interpretation and recommendation to marketing teams

# %% [markdown]
# #### Task 1.2 - Conduct an exploratory data analysis on those data & communicate useful insights. Ensure that you identify and treat all missing values and outliers in the dataset by replacing by the mean of the corresponding column.
